# %%
from sklearn.decomposition import PCA
from FileIO import FileIO
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %%
io = FileIO()
exps = io.load_experiment('s1')
emg = exps['S1_E1_A1']['emg']
glove = exps['S1_E1_A1']['glove']

# %%
plt.figure(figsize = [10,5*22])
for i in range(22):
    plt.subplot(22,1,i+1)
    plt.plot(glove[:1000,i])

# %%
x = emg[:,0]

# %%
plt.plot(x[:10000])

# %%
pca.components_.shape
# Out:
# (10, 16)

# %%
plt.plot(pca.components_[0])

# %%
pca = PCA(n_components=10, svd_solver='full')
pca.fit(emg)
plt.plot(np.cumsum(pca.explained_variance_ratio_))

# %%
t = pca.transform(emg)
fig = px.line_3d(df, x="gdpPercap", y="pop", z="year")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-bbcebbc37c58> in <module>
#       1 t = pca.transform(emg)
# ----> 2 fig = px.line_3d(df, x="gdpPercap", y="pop", z="year")
#       3 fig.show()
#
# NameError: name 'df' is not defined

# %%
fig = go.Figure(data=go.Scatter3d(
    x=t[1000:0], y=t[1000:1], z=t[1000:2],
    line=dict(
        color='darkblue',
        width=2
    )
))
fig.show()

# %%
exps['S1_E1_A1'].keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'emg', 'acc', 'stimulus', 'glove', 'subject', 'exercise', 'repetition', 'restimulus', 'rerepetition', 'age', 'circumference', 'frequency', 'gender', 'height', 'weight', 'laterality', 'sensor'])

# %%
exps['S1_E1_A1']['glove'].shape
# Out:
# (130267, 22)
